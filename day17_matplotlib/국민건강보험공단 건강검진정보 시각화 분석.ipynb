# %% [markdown]
# # import 기본적인 모듈 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from matplotlib import font_manager, rc

# %%
import matplotlib.font_manager as fm

# 현재 local에 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXGeneral',
#  'DejaVu Sans Display',
#  'cmmi10',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'cmtt10',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmr10',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'cmb10',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'cmss10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXVariants',
#  '.SF NS Mono',
#  'System Font',
#  'Noto Sans Kaithi',
#  'Mukta Mahee',
#  'Sathu',
#  'Noto Sans Gothic',
#  'Noto Sans Khudawadi',
#  'Noto Sans Kayah Li',
#  'Noto Sans Samaritan',
#  'Thonburi',
#  '.Keyboard',
#  'Tahoma',
#  'Noto Sans Old Permic',
#  'Courier New',
#  'STIXGeneral',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Brahmi',
#  'Arial Narrow',
#  'Helvetica Neue',
#  'Noto Sans Warang Citi',
#  'Verdana',
#  'Noto Sans Old Turkic',
#  'Charter',
#  'Hiragino Sans',
#  'Tamil MN',
#  'Palatino',
#  'STIXIntegralsUpSm',
#  'Times New Roman',
#  'Kefa',
#  'Bradley Hand',
#  'Noto Sans Duployan',
#  'Noto Sans Tai Le',
#  'Noto Sans Tagalog',
#  'Avenir',
#  'Wingdings 3',
#  'Georgia',
#  'Baskerville',
#  'Noto Sans Glagolitic',
#  'Noto Sans Psalter Pahlavi',
#  'STIXSizeFourSym',
#  'Hiragino Sans',
#  'Marion',
#  'STIXSizeOneSym',
#  'Symbol',
#  'STIXSizeFourSym',
#  'Noto Sans Ugaritic',
#  'Noto Sans Buhid',
#  'Noto Sans New Tai Lue',
#  'Heiti TC',
#  'Sinhala MN',
#  'Rockwell',
#  'STIXSizeFiveSym',
#  'Noto Sans Wancho',
#  'Noto Sans NKo',
#  'Apple Braille',
#  'Bodoni 72 Oldstyle',
#  'Kannada Sangam MN',
#  'Noto Sans Old Persian',
#  'STIXSizeOneSym',
#  'Noto Sans Myanmar',
#  '.SF NS Rounded',
#  'Noto Sans Rejang',
#  'STIXGeneral',
#  'Arial',
#  'Noto Sans Oriya',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Hiragino Mincho ProN',
#  'Noto Sans Tifinagh',
#  'Noto Sans Elbasan',
#  'Galvji',
#  'DecoType Naskh',
#  'Wingdings',
#  'Hiragino Sans',
#  'Noto Sans Meetei Mayek',
#  'STIXIntegralsSm',
#  'Noto Sans Phoenician',
#  'Apple SD Gothic Neo',
#  'Noto Sans Caucasian Albanian',
#  'Times',
#  'Noto Sans Cypriot',
#  'Noto Sans Marchen',
#  'Noto Sans Multani',
#  'Al Bayan',
#  'STIXIntegralsUp',
#  'Noto Sans Mahajani',
#  'Verdana',
#  'Georgia',
#  'STIXIntegralsD',
#  'Ayuthaya',
#  'Bodoni 72 Smallcaps',
#  'Noto Sans Carian',
#  'Arial',
#  'Tamil Sangam MN',
#  '.New York',
#  'Telugu Sangam MN',
#  'Noto Sans Takri',
#  'Noto Sans Inscriptional Parthian',
#  'Songti SC',
#  'Noto Sans Shavian',
#  'Trattatello',
#  'Hiragino Maru Gothic Pro',
#  'Gujarati MT',
#  'Waseem',
#  'Noto Sans Imperial Aramaic',
#  'Al Nile',
#  'Noto Sans Bassa Vah',
#  'DIN Alternate',
#  'ITF Devanagari',
#  'Verdana',
#  'Savoye LET',
#  'STIXSizeThreeSym',
#  'Papyrus',
#  'PT Sans',
#  'Marker Felt',
#  'Zapfino',
#  'Sinhala Sangam MN',
#  'Webdings',
#  'STIXGeneral',
#  'Noto Sans Tirhuta',
#  'Arial Narrow',
#  'Avenir Next Condensed',
#  'Noto Sans Bhaiksuki',
#  'Noto Serif Ahom',
#  'Arial Rounded MT Bold',
#  'Noto Sans Chakma',
#  'Khmer MN',
#  'Gurmukhi MT',
#  'Plantagenet Cherokee',
#  'Noto Sans Syriac',
#  'Geeza Pro',
#  '.Arabic UI Text',
#  'Trebuchet MS',
#  'Apple Braille',
#  'STIXIntegralsD',
#  'Oriya MN',
#  'Athelas',
#  'Noto Sans Lisu',
#  'PT Serif Caption',
#  'Copperplate',
#  'Noto Sans Old Hungarian',
#  'Diwan Kufi',
#  'Noto Sans Nabataean',
#  'Party LET',
#  'Noto Sans Sora Sompeng',
#  'Superclarendon',
#  'Khmer Sangam MN',
#  'Helvetica',
#  'Phosphate',
#  'Bangla Sangam MN',
#  'Chalkboard SE',
#  'Hiragino Sans',
#  'Noto Sans Thaana',
#  'Verdana',
#  'Snell Roundhand',
#  'Noto Sans Osage',
#  'Mshtakan',
#  'Courier New',
#  'STIXSizeThreeSym',
#  'Academy Engraved LET',
#  'Noto Sans Old South Arabian',
#  'STIXNonUnicode',
#  'Noto Sans Cham',
#  'Noto Sans Syloti Nagri',
#  'Arial',
#  'Malayalam Sangam MN',
#  'Apple Braille',
#  'Zapf Dingbats',
#  '.Aqua Kana',
#  'Brush Script MT',
#  'Beirut',
#  'Farah',
#  'Muna',
#  'STIXNonUnicode',
#  'Noto Sans Coptic',
#  'Bangla MN',
#  'Sukhumvit Set',
#  'STIXIntegralsUpD',
#  'Noto Sans Hanunoo',
#  'AppleGothic',
#  'STIXVariants',
#  'Cochin',
#  'Impact',
#  'Didot',
#  'Hoefler Text',
#  'Iowan Old Style',
#  'STIXSizeTwoSym',
#  'KufiStandardGK',
#  'Noto Sans Miao',
#  '.SF Compact Rounded',
#  'Times New Roman',
#  'Kohinoor Devanagari',
#  'Noto Sans Mandaic',
#  'Silom',
#  'Baghdad',
#  'Kohinoor Telugu',
#  'Noto Sans Hatran',
#  'Noto Sans Sundanese',
#  'Noto Sans Newa',
#  'STIXSizeTwoSym',
#  'Apple Braille',
#  'Hiragino Sans',
#  'Noto Sans Batak',
#  'Noto Sans Avestan',
#  'Courier New',
#  'Arial Narrow',
#  'Gurmukhi Sangam MN',
#  'Apple Symbols',
#  'Noto Sans Modi',
#  'Futura',
#  'Damascus',
#  'Hiragino Sans',
#  'Noto Sans Sharada',
#  '.SF Compact',
#  'Myanmar Sangam MN',
#  'Euphemia UCAS',
#  'Shree Devanagari 714',
#  'Tahoma',
#  'Noto Sans Manichaean',
#  'Skia',
#  'Noto Nastaliq Urdu',
#  'Noto Sans Siddham',
#  'Microsoft Sans Serif',
#  'Lao Sangam MN',
#  'STIXNonUnicode',
#  'Wingdings 2',
#  'Arial Unicode MS',
#  'Comic Sans MS',
#  'Noto Sans Linear B',
#  'Noto Sans Runic',
#  'Bodoni Ornaments',
#  'STIXIntegralsUp',
#  'Mishafi',
#  'Oriya Sangam MN',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Buginese',
#  'Noto Sans Cuneiform',
#  'STIXIntegralsSm',
#  'Times New Roman',
#  'System Font',
#  'Arial',
#  'Noto Sans Mende Kikakui',
#  '.New York',
#  'Georgia',
#  'Sana',
#  'PT Serif',
#  'Menlo',
#  'Nadeem',
#  'Malayalam MN',
#  'Telugu MN',
#  'Krungthep',
#  'Noto Sans Old Italic',
#  'Noto Sans Hanifi Rohingya',
#  'Avenir Next',
#  'Al Tarikh',
#  'Noto Sans Armenian',
#  'Kannada MN',
#  '.Arabic UI Display',
#  'Georgia',
#  'Noto Sans Linear A',
#  'Gujarati Sangam MN',
#  'Heiti TC',
#  'Kokonor',
#  'Noto Serif Myanmar',
#  'Noto Sans Osmanya',
#  'Hiragino Sans GB',
#  'Trebuchet MS',
#  'Seravek',
#  'Chalkboard',
#  'Noto Sans Tai Viet',
#  '.SF NS Mono',
#  'Gurmukhi MN',
#  'Arial Unicode MS',
#  'Bodoni 72',
#  'Farisi',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'Noto Sans Bamum',
#  'Noto Sans Ogham',
#  'Devanagari MT',
#  'Arial Hebrew',
#  'Lucida Grande',
#  'Noteworthy',
#  'Noto Sans Vai',
#  'STIXIntegralsUpSm',
#  'Noto Sans Lycian',
#  'SignPainter',
#  'Myanmar MN',
#  'Kailasa',
#  'Noto Sans Pahawh Hmong',
#  'Hoefler Text',
#  'AppleMyungjo',
#  'InaiMathi',
#  'Corsiva Hebrew',
#  'Noto Sans Tai Tham',
#  'Noto Sans Old North Arabian',
#  'Optima',
#  'Chalkduster',
#  'Apple Braille',
#  'Trebuchet MS',
#  'Diwan Thuluth',
#  'Noto Sans Yi',
#  'Noto Sans Inscriptional Pahlavi',
#  'Herculanum',
#  'DIN Condensed',
#  'Trebuchet MS',
#  'Noto Sans Khojki',
#  'Noto Sans PhagsPa',
#  'Noto Sans Pau Cin Hau',
#  '.SF Compact',
#  'Luminari',
#  'Hiragino Sans',
#  'New Peninim MT',
#  'Noto Sans Mongolian',
#  'Big Caslon',
#  'Mishafi Gold',
#  'Noto Serif Balinese',
#  'Kohinoor Bangla',
#  'Courier New',
#  'Apple Chancery',
#  'STIXGeneral',
#  'Noto Sans Javanese',
#  'Kohinoor Gujarati',
#  'STIXIntegralsUpD',
#  'PT Mono',
#  'Lao MN',
#  'Comic Sans MS',
#  'Gill Sans',
#  'Noto Sans Kannada',
#  'PingFang HK',
#  'Noto Sans Ol Chiki',
#  'Andale Mono',
#  'Noto Sans Limbu',
#  'Arial Black',
#  'Devanagari Sangam MN',
#  'Noto Sans Saurashtra',
#  'Noto Sans Palmyrene',
#  'Noto Sans Meroitic',
#  'Times New Roman',
#  'Noto Sans Lydian',
#  'American Typewriter',
#  'Hiragino Sans',
#  'Hiragino Sans',
#  'Raanana',
#  'Noto Sans Mro',
#  'Noto Sans Lepcha',
#  'Arial Narrow',
#  'Noto Sans Adlam']

# %%
# 윈도우
# plt.rcParams['font.family'] = 'D2Coding'
# 맥
plt.rcParams['font.family'] = 'AppleGothic'

# %%
df = pd.read_csv('국민건강보험공단_건강검진정보_20191231.csv', encoding='euc-kr')

# %%
df.head()
# Out:
#    기준년도  가입자 일련번호  시도코드  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0  2019         1    11     1            13        165          65  90.0
# 1  2019         2    48     2             5        155          45  64.0
# 2  2019         3    41     1            13        160          70  87.0
# 3  2019         4    28     1            12        170          60  85.0
# 4  2019         5    41     1            10        170          70  81.2
#
#    시력(좌)  시력(우)  ...  감마 지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치 유무  치아마모증유무  \
# 0    1.5    1.2  ...    47.0   2.0   NaN          1      0.0     미시행      미시행
# 1    1.2    0.5  ...    13.0   1.0   1.0          0      NaN     미시행      미시행
# 2    0.9    0.8  ...    17.0   1.0   1.0          0      NaN     미시행      미시행
# 3    0.4    1.2  ...    32.0   2.0   1.0          0      NaN     미시행      미시행
# 4    0.7    0.7  ...    19.0   2.0   NaN          0      NaN     미시행      미시행
#
#    제3대구치(사랑니) 이상   치석  데이터 공개일자
# 0            미시행  1.0  20191231
# 1            미시행  NaN  20191231
# 2            미시행  NaN  20191231
# 3            미시행  NaN  20191231
# 4            미시행  NaN  20191231
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#             기준년도        가입자 일련번호            시도코드            성별코드  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2019.0   500000.500000       33.712386        1.480426
# std          0.0   288675.278933       12.668197        0.499617
# min       2019.0        1.000000       11.000000        1.000000
# 25%       2019.0   250000.750000       27.000000        1.000000
# 50%       2019.0   500000.500000       41.000000        1.000000
# 75%       2019.0   750000.250000       43.000000        2.000000
# max       2019.0  1000000.000000       50.000000        2.000000
#
#          연령대 코드(5세단위)       신장(5Cm단위)      체중(5Kg 단위)           허리둘레  \
# count  1000000.000000  1000000.000000  1000000.000000  999597.000000
# mean        10.496387      162.307655       63.564490      81.320565
# std          2.964080        9.280317       12.877611      10.523122
# min          5.000000      130.000000       30.000000       3.000000
# 25%          8.000000      155.000000       55.000000      74.000000
# 50%         11.000000      160.000000       60.000000      81.000000
# 75%         13.000000      170.000000       70.000000      88.000000
# max         18.000000      195.000000      145.000000     999.000000
#
#                시력(좌)          시력(우)  ...        혈청크레아티닌     (혈청지오티)AST  \
# count  999805.000000  999812.000000  ...  994474.000000  994478.000000
# mean        0.971909       0.970951  ...       0.860555      26.231107
# std         0.593307       0.600537  ...       0.477701      24.046478
# min         0.100000       0.100000  ...       0.060000       1.000000
# 25%         0.700000       0.700000  ...       0.700000      19.000000
# 50%         1.000000       1.000000  ...       0.800000      23.000000
# 75%         1.200000       1.200000  ...       1.000000      29.000000
# max         9.900000       9.900000  ...      98.000000    7362.000000
#
#           (혈청지오티)ALT         감마 지티피           흡연상태           음주여부  \
# count  994477.000000  994470.000000  999834.000000  644918.000000
# mean       25.996708      36.294294       1.369669       0.999972
# std        27.710895      48.390706       0.482715       0.005283
# min         1.000000       1.000000       1.000000       0.000000
# 25%        15.000000      16.000000       1.000000       1.000000
# 50%        20.000000      23.000000       1.000000       1.000000
# 75%        30.000000      39.000000       2.000000       1.000000
# max      6435.000000     999.000000       2.000000       1.000000
#
#             구강검진 수검여부        치아우식증유무             치석    데이터 공개일자
# count  1000000.000000  397680.000000  397680.000000   1000000.0
# mean         0.397680       0.210068       0.587523  20191231.0
# std          0.489419       0.407357       0.589261         0.0
# min          0.000000       0.000000       0.000000  20191231.0
# 25%          0.000000       0.000000       0.000000  20191231.0
# 50%          0.000000       0.000000       1.000000  20191231.0
# 75%          1.000000       0.000000       1.000000  20191231.0
# max          1.000000       1.000000       2.000000  20191231.0
#
# [8 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   기준년도           1000000 non-null  int64
#  1   가입자 일련번호       1000000 non-null  int64
#  2   시도코드           1000000 non-null  int64
#  3   성별코드           1000000 non-null  int64
#  4   연령대 코드(5세단위)   1000000 non-null  int64
#  5   신장(5Cm단위)      1000000 non-null  int64
#  6   체중(5Kg 단위)     1000000 non-null  int64
#  7   허리둘레           999597 non-null   float64
#  8   시력(좌)          999805 non-null   float64
#  9   시력(우)          999812 non-null   float64
#  10  청력(좌)          999819 non-null   float64
#  11  청력(우)          999822 non-null   float64
#  12  수축기 혈압         994576 non-null   float64
#  13  이완기 혈압         994575 non-null   float64
#  14  식전혈당(공복혈당)     994477 non-null   float64
#  15  총 콜레스테롤        333549 non-null   float64
#  16  트리글리세라이드       333544 non-null   float64
#  17  HDL 콜레스테롤      333541 non-null   float64
#  18  LDL 콜레스테롤      327148 non-null   float64
#  19  혈색소            994468 non-null   float64
#  20  요단백            989694 non-null   float64
#  21  혈청크레아티닌        994474 non-null   float64
#  22  (혈청지오티)AST     994478 non-null   float64
#  23  (혈청지오티)ALT     994477 non-null   float64
#  24  감마 지티피         994470 non-null   float64
#  25  흡연상태           999834 non-null   float64
#  26  음주여부           644918 non-null   float64
#  27  구강검진 수검여부      1000000 non-null  int64
#  28  치아우식증유무        397680 non-null   float64
#  29  결손치 유무         1000000 non-null  object
#  30  치아마모증유무        1000000 non-null  object
#  31  제3대구치(사랑니) 이상  1000000 non-null  object
#  32  치석             397680 non-null   float64
#  33  데이터 공개일자       1000000 non-null  int64
# dtypes: float64(22), int64(9), object(3)
# memory usage: 259.4+ MB

# %% [markdown]
# # NaN 결측치 존재

# %%
df.drop(['기준년도', '가입자 일련번호', '결손치 유무', '치아마모증유무', '제3대구치(사랑니) 이상', '데이터 공개일자'], inplace=True, axis=1)

# %%
df.rename(columns={'연령대 코드(5세단위)':'연령코드', '신장(5cm단위)':'신장', '체중(5kg단위)':'체중', '식전혈당(공복혈당)':'혈당'}, inplace=True)

# %%
# 결측치 처리
df = df.dropna()

# %%
df
# Out:
#         시도코드  성별코드  연령코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 6         41     1     6        175          70  81.3    0.9    1.0    1.0
# 26        46     1    10        170          75  83.0    0.5    0.7    1.0
# 41        47     1     5        175          90  93.0    1.2    1.2    1.0
# 63        41     2    10        155          55  74.9    1.2    1.2    1.0
# 72        41     1     9        180          75  90.1    1.2    1.2    1.0
# ...      ...   ...   ...        ...         ...   ...    ...    ...    ...
# 999937    11     1     9        170          55  74.0    0.8    1.0    1.0
# 999941    45     1    10        170          75  88.5    1.5    0.5    1.0
# 999944    43     2     9        160          55  78.0    1.5    1.5    1.0
# 999961    41     1    13        160          75  93.0    1.2    1.2    1.0
# 999976    11     2    13        160          55  76.0    0.6    0.6    1.0
#
#         청력(우)  ...  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마 지티피  흡연상태  음주여부  \
# 6         1.0  ...  1.0      0.9        14.0        11.0    30.0   2.0   1.0
# 26        1.0  ...  1.0      0.8        26.0        41.0    32.0   2.0   1.0
# 41        1.0  ...  1.0      0.7        29.0        37.0    26.0   1.0   1.0
# 63        1.0  ...  1.0      0.9        17.0         9.0     8.0   1.0   1.0
# 72        1.0  ...  2.0      1.2        28.0        20.0    18.0   1.0   1.0
# ...       ...  ...  ...      ...         ...         ...     ...   ...   ...
# 999937    1.0  ...  1.0      1.0        25.0        33.0   118.0   2.0   1.0
# 999941    1.0  ...  2.0      1.0        16.0        10.0    87.0   2.0   1.0
# 999944    1.0  ...  1.0      0.7        20.0        13.0    14.0   1.0   1.0
# 999961    1.0  ...  1.0      0.7        30.0        34.0    86.0   2.0   1.0
# 999976    1.0  ...  1.0      0.7        29.0        24.0    14.0   1.0   1.0
#
#         구강검진 수검여부  치아우식증유무   치석
# 6               1      0.0  0.0
# 26              1      0.0  1.0
# 41              1      0.0  1.0
# 63              1      0.0  2.0
# 72              1      0.0  0.0
# ...           ...      ...  ...
# 999937          1      0.0  0.0
# 999941          1      0.0  1.0
# 999944          1      0.0  2.0
# 999961          1      1.0  1.0
# 999976          1      0.0  0.0
#
# [78485 rows x 28 columns]

# %%
# 의미해석이 아니라 뭐가 있는지 보여주려고
# sns.pairplot(df)

# %%
# 위 코드칸이 오래 걸려서 5개만 끊어서 출력
sns.pairplot(df.iloc[:, :5])

# %%
fig, axs = plt.subplots(5, 5)
fig.set_size_inches(20, 24)

for i in range(5):
    for j in range(5):
        attr = i * 5 + j + 1
        if df[df.columns[attr]].nunique() < 30:
            sns.countplot( x= df.columns[attr], data=df, ax=axs[i][j])
        else:
            sns.histplot(x=df.columns[attr], data=df, kde=True, ax=axs[i][j])

# %%
# 음주 여부 [1번 이상 / 0번]
df['음주여부'].value_counts()
# Out:
# 1.0    78481
# 0.0        4
# Name: 음주여부, dtype: int64

# %%
sns.scatterplot(x=df['수축기 혈압'], y=df['이완기 혈압'], hue=df['흡연상태'])
# Out:
# <AxesSubplot:xlabel='수축기 혈압', ylabel='이완기 혈압'>

# %%
sns.lineplot(x=df['연령코드'],y=df['총 콜레스테롤'])
# Out:
# <AxesSubplot:xlabel='연령코드', ylabel='총 콜레스테롤'>

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(x=df['연령코드'],y=df['혈색소'])
# Out:
# <AxesSubplot:xlabel='연령코드', ylabel='혈색소'>

# %%
pivot_df = df.pivot_table('혈당','시도코드','연령코드')
sns.heatmap(pivot_df)
# Out:
# <AxesSubplot:xlabel='연령코드', ylabel='시도코드'>
